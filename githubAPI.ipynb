# %%
# !pip install ghapi

# %%
import os
from ghapi.core import GhApi

# %%
from google.colab import userdata
github_token = userdata.get('GITHUB_TOKEN')

# %%
api = GhApi(owner="Kumar0408", repo="wandb-cicd", token=github_token)
for pr in api.pulls.list():
  print(pr.number, pr.title, pr.html_url)

# %%
api.actions.list_workflow_runs_for_repo()

# %%
api.issues.create_comment(3,"Hi I am making a comment with GH api")

# %%
api.issues.add_labels(3, labels=['ghapi-demo'])
